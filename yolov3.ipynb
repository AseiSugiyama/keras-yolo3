# %% [markdown]
# <a href="https://colab.research.google.com/github/AseiSugiyama/keras-yolo3/blob/master/yolov3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook runs YOLO-v3.
# Original document is [KerasのYOLO-v3を動かしたった - Qiita](https://qiita.com/yoyoyo_/items/10d550b03b4b9c175d9c)

# %%
try:
  # %tensorflow_version 1.x
except Exception:
  pass
import tensorflow as tf

# %%
tf.__version__
# Out:
# '1.15.0'

# %%
# !git clone https://github.com/AseiSugiyama/keras-yolo3.git
# Out:
# Cloning into 'keras-yolo3'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 148 (delta 0), reused 1 (delta 0), pack-reused 145
# Receiving objects: 100% (148/148), 154.75 KiB | 825.00 KiB/s, done.
# Resolving deltas: 100% (66/66), done.

# %%
cd keras-yolo3
# Out:
# /content/keras-yolo3

# %%
# !wget https://pjreddie.com/media/files/yolov3.weights
# Out:
# --2019-11-17 07:03:10--  https://pjreddie.com/media/files/yolov3.weights
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248007048 (237M) [application/octet-stream]
# Saving to: ‘yolov3.weights’
#
# yolov3.weights      100%[===================>] 236.52M  18.4MB/s    in 13s
#
# 2019-11-17 07:03:24 (17.7 MB/s) - ‘yolov3.weights’ saved [248007048/248007048]

# %%
# !python convert.py yolov3.cfg yolov3.weights model_data/yolo.h5
# Out:
# Loading weights.
# Weights Header:  0 2 0 [32013312]
# Parsing Darknet config.
# Creating Keras model.
# Parsing section net_0
# Parsing section convolutional_0
# conv2d bn leaky (3, 3, 3, 32)
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# 2019-11-17 07:03:28.989524: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-17 07:03:29.058729: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# ...

# %% [markdown]
# # Update horse image
#
# We should upload horse image by hand under `keras-yolo3` folder using left pane. Then run following code cell.

# %%
# !python yolo.py
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From yolo.py:44: The name tf.keras.backend.get_session is deprecated. Please use tf.compat.v1.keras.backend.get_session instead.
#
# 2019-11-17 07:04:40.064703: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2019-11-17 07:04:40.077240: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2019-11-17 07:04:40.077864: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla P100-PCIE-16GB major: 6 minor: 0 memoryClockRate(GHz): 1.3285
# pciBusID: 0000:00:04.0
# 2019-11-17 07:04:40.078136: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.0
# ...
